# %%
from collections import Counter
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

file = pd.read_csv('restaurant-and-market-health-violations.csv')
df = pd.DataFrame(file)
df
# Out:
#        serial_number        activity_date               facility_name  \
# 0          DA08R0TCU  2018-03-30T00:00:00                 KRUANG TEDD
# 1          DA08R0TCU  2018-03-30T00:00:00                 KRUANG TEDD
# 2          DA08R0TCU  2018-03-30T00:00:00                 KRUANG TEDD
# 3          DA08R0TCU  2018-03-30T00:00:00                 KRUANG TEDD
# 4          DA08R0TCU  2018-03-30T00:00:00                 KRUANG TEDD
# 5          DA08R0TCU  2018-03-30T00:00:00                 KRUANG TEDD
# 6          DA08R0TCU  2018-03-30T00:00:00                 KRUANG TEDD
# 7          DA0GBKW3F  2018-03-30T00:00:00  SPROUTS FARMERS MARKET#403
# 8          DA0GBKW3F  2018-03-30T00:00:00  SPROUTS FARMERS MARKET#403
# 9          DA0GBKW3F  2018-03-30T00:00:00  SPROUTS FARMERS MARKET#403
# 10         DA0HEAJNR  2018-03-30T00:00:00  LOS ANGELES NEW YORK PIZZA
# 11         DA0HEAJNR  2018-03-30T00:00:00  LOS ANGELES NEW YORK PIZZA
# ...

# %%
grade = df['grade']
count = Counter(grade)

print(count)
# Out:
# Counter({'A': 234707, 'B': 34363, 'C': 3731})

# %%
from matplotlib import reload
reload(plt)
# %matplotlib notebook
df['score'].hist().plot()

# plots most common scores by frequency
# Out:
# <img src="data:image/png;base64,..." width="640">
# []

# %%
# build a map showing clusters by grade
